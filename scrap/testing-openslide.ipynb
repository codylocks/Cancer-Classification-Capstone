# %%
import openslide

# %%
test_image = openslide.open_slide(
    './inital_sample_4_items/gdc_download_20200519_034845.104976/2335c95c-9c6f-4038-8272-ba1464d6670e/TCGA-HT-7902-01Z-00-DX1.B9265DE0-438A-4D0E-A828-EE5019422E0C.svs')

# %%
test_image.get_thumbnail((1000,1000))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x405 at 0x11166EE10>

# %%
test_image.

# %%
    slide_stats()
